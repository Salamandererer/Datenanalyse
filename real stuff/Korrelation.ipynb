# %% [markdown]
# # Korrelation
#
#
# Hier befindet sich die Berechnung zur Korrelation  zwischen den Views einer gewählten Seite und der aufsummierten Views aller Backlinks berechnet. Die Eingabe dieser Seiter erfolgt unter "article", welche man in zwei Zellen unter dieser hier findet.
#
# Hier werden zudem Backlinks rausgefiltert, die zu viele leere Einträge haben. Diese Grenze liegt bei ca 180 Einträgen, also einem halben Jahr.
#
#
# Die Korrelation liefert den linearen Zusammenhang zwischen zwei Variablen.
#
#
# Die Korrelation liegt immer zwischen -1 und 1. Wobei 0 bedeutet, dass kein linearer Zusammenhang besteht. -1 oder 1 bedeuten, dass ein stärkerer linearer Zusammenhang oder ein schwächerer besteht.

# %%
import os
import pandas as pd

from linkmethods import get_views,filterlinks,get_links

# %%
#Type in the Wikipedia page you want to get data from

# %%
article = "Exekutive"

# %%
#grab all backlinks from one page

# %%
all_main_backlinks = get_links(article,"linkshere")

# %%
#writing the data to a csv for later use to save time, also filtering not necessary backlinks from the list

# %%
filter_all_backlinks = filterlinks(all_main_backlinks)
df = pd.DataFrame(filter_all_backlinks,columns=["backlinks"])
path = fr"datafiles\{article}"
try:
    os.mkdir(path) #write it to a csv for later use
except:
    pass
df.to_csv(path + '/' f'{article}bldata.csv', index=False)

# %%
#Comparing the amount of all links and the amount of links after they got filtered

# %%
print("Number of unfiltered Pages:",len(all_main_backlinks))
print("Number of pages after filter:",(len(filter_all_backlinks)))
# Out:
# Number of unfiltered Pages: 2000
# Number of pages after filter: 1727

# %%
#Consider the Runtime increases proportional to the amount of unfiltered Pages

# %%
filter_all_backlinks = pd.read_csv(fr"datafiles\{article}\{article}bldata.csv")
filter_all_backlinks = filter_all_backlinks['backlinks'].values.tolist()

# %%
print(pd.DataFrame(filter_all_backlinks,columns=[f"Backlinks from {article}"]))
#Getting a look at the Backlinks
# Out:
#                   Backlinks from Exekutive
# 0                             Adolf Hitler
# 1                                 Algerien
# 2     Betäubungsmittelgesetz (Deutschland)
# 3                                 Bodensee
# 4                  Freie Hansestadt Bremen
# ...                                    ...
# 1722   Kolumbianische Verwaltungseinheiten
# 1723                     Karl-Heinz Zeller
# 1724                        Rahel Bänziger
# 1725                           Peter Peyer
# 1726                       Dimitri Moretti
#
# [1727 rows x 1 columns]

# %%
#Filling up the array with 0's on the days no data is availible -  meaning there were no pageviews on that day
#Additionally we are not using pages where the page has more than 1/14 missing entrys (line 10)

# %%
mainviews = get_views(article)
backlinksMainview = filterlinks(get_links(article,"linkshere"))

len1 = len(mainviews)
for entry in backlinksMainview:
    views = get_views(entry)
    len2 = len(views)
    if len2 < len1:
        diff = len1 - len2
        if diff < len(mainviews)/14:
            print("Filling in",diff,"Missing Values for:",entry)
            for i in range(0, diff):
                views.append(0)
        else:
            backlinksMainview.remove(entry)

entrys = [0]*len(mainviews)

for position,entry in enumerate(backlinksMainview):
    print("Working on...", entry)
    list = get_views(entry)
    print("at" ,position ,"/", len(backlinksMainview))
    for i in range(0,len(list)):
        entrys[i] = entrys[i] + list[i]
# Out:
# Filling in 1 Missing Values for: 1710
# Filling in 83 Missing Values for: Dnipro
# Filling in 3 Missing Values for: Länderkammer der DDR
# Filling in 3 Missing Values for: Stein AR
# Filling in 34 Missing Values for: Bezirkstag (DDR)
# Filling in 136 Missing Values for: Dezember 2003
# Filling in 24 Missing Values for: Cornaux
# Filling in 42 Missing Values for: Krone von Aragonien
# Filling in 74 Missing Values for: Hans Streuli
# Filling in 2 Missing Values for: Provinzverwaltung in Finnland
# Filling in 32 Missing Values for: E-Administration
# Filling in 3 Missing Values for: Walter Zirpins
# Filling in 3 Missing Values for: Conthey
# Filling in 1 Missing Values for: Kanzlerdemokratie
# Filling in 95 Missing Values for: Artikel 8 des Grundgesetzes für die Bundesrepublik Deutschland
# Filling in 63 Missing Values for: Départementrat
# Filling in 14 Missing Values for: Landesbetrieb für Küstenschutz, Nationalpark und Meeresschutz Schleswig-Holstein
# Filling in 6 Missing Values for: Hans Fehr (Politiker)
# Filling in 1 Missing Values for: Meikirch
# Filling in 1 Missing Values for: Verwaltung im Alten Ägypten
# Filling in 6 Missing Values for: Sutz-Lattrigen
# Filling in 12 Missing Values for: Falkensteinerbund
# Filling in 22 Missing Values for: Verwaltungstransparenz
# Filling in 4 Missing Values for: Grub AR
# Filling in 3 Missing Values for: Lutzenberg AR
# Filling in 2 Missing Values for: Schönengrund
# Filling in 4 Missing Values for: Wald AR
# Filling in 2 Missing Values for: Frankfurter Fürstentag
# Filling in 21 Missing Values for: Gemeindehaus (Kommune)
# Filling in 40 Missing Values for: EuroCOP
# Filling in 3 Missing Values for: Grundsatz der Inkompatibilität
# Filling in 1 Missing Values for: Exekutivföderalismus
# Filling in 4 Missing Values for: Budgetrecht
# Filling in 1 Missing Values for: Franz Löschnak
# Filling in 7 Missing Values for: Gemeindevorsteher
# Filling in 6 Missing Values for: Thronrede
# Filling in 1 Missing Values for: Kroatien im Staatsverband mit Ungarn
# Filling in 9 Missing Values for: Burg Wartenberg (Hessen)
# Filling in 1 Missing Values for: Präsident der Europäischen Union
# Filling in 48 Missing Values for: Corcelles-Cormondrèche
# Filling in 68 Missing Values for: Freiburger Kantonalbank
# Filling in 158 Missing Values for: Banque Cantonale du Jura
# Filling in 64 Missing Values for: Nidwaldner Kantonalbank
# Filling in 69 Missing Values for: Obwaldner Kantonalbank
# Filling in 3 Missing Values for: Schaffhauser Kantonalbank
# Filling in 19 Missing Values for: Peseux NE
# Filling in 1 Missing Values for: Bürglen UR
# Filling in 1 Missing Values for: Hospental
# Filling in 107 Missing Values for: Hermann von Görtz-Wrisberg
# Filling in 17 Missing Values for: Chamoson
# Filling in 20 Missing Values for: Sembrancher
# Filling in 125 Missing Values for: Bovernier
# Filling in 1 Missing Values for: Dürrenroth
# Filling in 41 Missing Values for: Leytron
# Filling in 63 Missing Values for: Martigny-Combe
# Filling in 3 Missing Values for: Saxon VS
# Filling in 4 Missing Values for: Hofpfalzgraf
# Filling in 4 Missing Values for: Justizgrundrecht
# Filling in 50 Missing Values for: Präsident des Kontinentalkongresses
# Filling in 30 Missing Values for: Große Remonstranz
# Filling in 12 Missing Values for: Untergesetzliche Normsetzung
# Filling in 11 Missing Values for: Entschließung
# Filling in 1 Missing Values for: Verwaltungskompetenz
# Filling in 114 Missing Values for: NS-Staat
# Filling in 4 Missing Values for: Durchführungsbestimmung
# Filling in 20 Missing Values for: Schutzgebietsgesetz
# Filling in 10 Missing Values for: Zentralverband der Deutschen Werbewirtschaft
# Filling in 1 Missing Values for: Verpflichtungsermächtigung
# Filling in 1 Missing Values for: Astano
# Filling in 60 Missing Values for: Ulrich Ilg
# Filling in 7 Missing Values for: Peter Hans
# Filling in 7 Missing Values for: Meltingen
# No Data Availible for: Deutscher Bundestag
# Filling in 3 Missing Values for: Normverwerfungskompetenz
# Filling in 1 Missing Values for: Woiwodschaftsmarschall
# Filling in 1 Missing Values for: Haushaltsgesetz
# Filling in 19 Missing Values for: Boningen
# Filling in 81 Missing Values for: Landgericht Offenburg
# Filling in 2 Missing Values for: Machthaber
# Filling in 101 Missing Values for: Gewaltenkontrolle
# Filling in 7 Missing Values for: Moshoeshoe II.
# Filling in 2 Missing Values for: Konstantin Kammerhofer
# Filling in 3 Missing Values for: Richterliche Selbstbeschränkung
# Filling in 13 Missing Values for: Ferguson Research
# Filling in 76 Missing Values for: Scotland Act 1998
# Filling in 34 Missing Values for: Irakische Verfassung von 2005
# Filling in 4 Missing Values for: Antifaschistischer Rat der Nationalen Befreiung Jugoslawiens
# Filling in 3 Missing Values for: Offenburger Versammlung 1847
# Filling in 82 Missing Values for: Revolutionärer Kommandorat
# Filling in 26 Missing Values for: Maurice Duverger
# Filling in 1 Missing Values for: Innerer Notstand
# Filling in 78 Missing Values for: Dimitar Peschew
# Filling in 68 Missing Values for: Lachout-Dokument
# Filling in 25 Missing Values for: Reichsversicherungsamt
# Filling in 34 Missing Values for: Nationalbank der Ukraine
# Filling in 3 Missing Values for: American Platinum Eagle
# Filling in 22 Missing Values for: Claude Janiak
# Filling in 88 Missing Values for: Peter Bieri (Politiker)
# Filling in 72 Missing Values for: Thomas McKean
# Filling in 4 Missing Values for: Mahendra
# Filling in 118 Missing Values for: Signing Statement
# Filling in 3 Missing Values for: Verbot des Einzelfallgesetzes
# Filling in 1 Missing Values for: Oktoberedikt
# Filling in 7 Missing Values for: Uplift-Universum
# Filling in 2 Missing Values for: Politisches System Namibias
# Filling in 3 Missing Values for: Hongkong-Englisch
# Filling in 1 Missing Values for: Lord Lieutenant of Ireland
# Filling in 31 Missing Values for: Konföderation Irland
# Filling in 1 Missing Values for: Jacques Doriot
# Filling in 1 Missing Values for: Marcel Déat
# Filling in 48 Missing Values for: Richtplan
# Filling in 8 Missing Values for: Geschichte des Senats der Vereinigten Staaten
# Filling in 42 Missing Values for: Paulus van Husen
# Filling in 73 Missing Values for: Barbara Egger-Jenzer
# Filling in 9 Missing Values for: Agadez (Region)
# Filling in 21 Missing Values for: Liste der Chief Minister in Indien
# Filling in 2 Missing Values for: Römische Republik (1798–1799)
# Filling in 1 Missing Values for: Verwaltungshoheit
# Filling in 27 Missing Values for: Stimmberechtigte
# Filling in 16 Missing Values for: Sicherheitskräfte
# Filling in 33 Missing Values for: September 2006
# Filling in 87 Missing Values for: George Read
# Filling in 9 Missing Values for: Beamtenstaat
# Filling in 29 Missing Values for: Rat der Danziger
# Filling in 8 Missing Values for: Consejo de Indias
# Filling in 3 Missing Values for: Schlichte Hoheitsverwaltung
# Filling in 105 Missing Values for: Politisches System Sambias
# Filling in 155 Missing Values for: Tahoua (Region)
# Filling in 180 Missing Values for: Zinder (Region)
# Filling in 24 Missing Values for: Bundesratsinitiative
# Filling in 26 Missing Values for: Blauparadiesvogel
# Filling in 70 Missing Values for: Finanzkontrolle
# Filling in 47 Missing Values for: Polizia Provinciale
# Filling in 46 Missing Values for: Montes Claros
# Filling in 89 Missing Values for: Ipatinga
# Filling in 140 Missing Values for: Trix Heberlein
# Filling in 1 Missing Values for: Spiringen
# Filling in 1 Missing Values for: Seedorf UR
# Filling in 1 Missing Values for: Eberhard Finckh
# Filling in 2 Missing Values for: Ulanen-Regiment „Kaiser Franz Josef von Österreich, König von Ungarn“ (1. Königlich Sächsisches) Nr. 17
# Filling in 36 Missing Values for: Chief Minister der Isle of Man
# Filling in 96 Missing Values for: Legislative Council (Isle of Man)
# Filling in 12 Missing Values for: Blanquismus
# Filling in 5 Missing Values for: Bill of Attainder
# Filling in 33 Missing Values for: Letizia Moratti
# Filling in 1 Missing Values for: Südtiroler Landesregierung
# Filling in 2 Missing Values for: Agrarpolitik in Deutschland
# Filling in 1 Missing Values for: Serbische Regierung
# Filling in 71 Missing Values for: Brigitte Häberli-Koller
# Filling in 7 Missing Values for: Bremer Stadtrecht
# Filling in 6 Missing Values for: Joseph Huber (Soziologe)
# Filling in 2 Missing Values for: Friedrich Wilhelm Schulz
# Filling in 1 Missing Values for: American Battle Monuments Commission
# Filling in 119 Missing Values for: Levi Woodbury
# Filling in 31 Missing Values for: Spanisches Verfassungsgericht
# Filling in 1 Missing Values for: Filippo Lombardi
# Filling in 72 Missing Values for: President’s rule
# Filling in 14 Missing Values for: Maximilian Reimann
# Filling in 2 Missing Values for: This Jenny
# Filling in 17 Missing Values for: Air Ministry
# Filling in 12 Missing Values for: Gleichmäßigkeit der Besteuerung
# Filling in 44 Missing Values for: Exekutiv-Yuan
# Filling in 28 Missing Values for: Josef Dittli
# Filling in 4 Missing Values for: Raad van State
# Filling in 16 Missing Values for: Hans Stöckli
# Filling in 1 Missing Values for: Illegaler Holzeinschlag
# Filling in 90 Missing Values for: Vollziehung
# Filling in 1 Missing Values for: Wehrmachtbefehlshaber
# Filling in 51 Missing Values for: Papierwerd
# Filling in 168 Missing Values for: Rondonópolis
# Filling in 97 Missing Values for: Bund der Steuerzahler (Schweiz)
# Filling in 66 Missing Values for: Hans Schneider (Jurist)
# Filling in 1 Missing Values for: Office of Management and Budget
# Filling in 4 Missing Values for: Richerzeche
# Filling in 158 Missing Values for: Innenministerium (Frankreich)
# Filling in 20 Missing Values for: Föderative
# Filling in 143 Missing Values for: Regierung der Republik Kroatien
# Filling in 31 Missing Values for: Volkspetition
# Filling in 146 Missing Values for: Amtsgericht Bremerhaven
# Filling in 103 Missing Values for: Verfassung der Philippinen
# Filling in 67 Missing Values for: Estnische Verfassung von 1992
# Filling in 9 Missing Values for: Polizei Berlin
# Filling in 6 Missing Values for: Polizeipräsidium (Dresden)
# Filling in 73 Missing Values for: Alex Hürzeler
# Filling in 40 Missing Values for: Türkische Verfassung von 1961
# Filling in 51 Missing Values for: Vertretung des Landes Bremen beim Bund
# Filling in 115 Missing Values for: Gouverneur (Volksrepublik China)
# Filling in 165 Missing Values for: Brigit Wyss
# Filling in 121 Missing Values for: Oktober 2000
# Filling in 99 Missing Values for: Hans Altherr
# Filling in 154 Missing Values for: Senat von Alaska
# Filling in 80 Missing Values for: Repräsentantenhaus von Illinois
# Filling in 72 Missing Values for: Senat von Massachusetts
# Filling in 85 Missing Values for: Senat von Pennsylvania
# Filling in 179 Missing Values for: Senat von South Dakota
# Filling in 2 Missing Values for: Portal:Solothurn
# Filling in 85 Missing Values for: Rechnungshof Baden-Württemberg
# Filling in 1 Missing Values for: Verfassung des Landes Schleswig-Holstein
# Filling in 96 Missing Values for: Helvetisches Direktorium
# Filling in 2 Missing Values for: Verwerfungskompetenz
# Filling in 57 Missing Values for: Elberfelder Aufstand
# Filling in 117 Missing Values for: Machtspruch
# Filling in 7 Missing Values for: Reute AR
# Filling in 138 Missing Values for: Grünes Bündnis (Bern)
# Filling in 20 Missing Values for: Joh. Springer’s Erben
# Filling in 50 Missing Values for: Vargas (Bundesstaat)
# Filling in 81 Missing Values for: Hans Hagemeyer
# Filling in 82 Missing Values for: Verfassung Namibias
# Filling in 65 Missing Values for: Liste der Stadtpräsidenten von Luzern
# Filling in 61 Missing Values for: Politisches System Kirgisistans
# Filling in 22 Missing Values for: Oberst Brecht (Boot)
# Filling in 135 Missing Values for: Markus Dieth
# Filling in 135 Missing Values for: Verfassung Argentiniens
# Filling in 70 Missing Values for: Sūmitsu-in
# Filling in 46 Missing Values for: Georges Scelle
# Filling in 23 Missing Values for: Verfassungsgericht der Tschechischen Republik
# Filling in 137 Missing Values for: Martin Löffler
# Filling in 7 Missing Values for: Unser Land (Partei)
# Filling in 21 Missing Values for: Kremsierer Entwurf
# Filling in 74 Missing Values for: Eidgenössische Volksinitiative «Rückkehr zur direkten Demokratie»
# Filling in 40 Missing Values for: Stanley Forman Reed
# Filling in 14 Missing Values for: Zivilschutz (Italien)
# Filling in 23 Missing Values for: Gemeinderat (Bern)
# Filling in 24 Missing Values for: Meiji Mura
# Filling in 97 Missing Values for: Kurhessische Verfassung von 1831
# Filling in 1 Missing Values for: Rick Scott
# Filling in 176 Missing Values for: Neues Gebäu (Chur)
# Filling in 63 Missing Values for: Richter (Frankreich)
# Filling in 14 Missing Values for: Staatsanwaltschaft (Frankreich)
# Filling in 17 Missing Values for: Politisches System Tunesiens
# Filling in 61 Missing Values for: Politisches System Ugandas
# Filling in 25 Missing Values for: Liste der Bürgermeister der Stadt Brilon
# Filling in 15 Missing Values for: Louisiana State Capitol
# Filling in 1 Missing Values for: Waffenkontrolle (Recht)
# Filling in 9 Missing Values for: Markus Ritter (Politiker)
# Filling in 15 Missing Values for: Bericht (Verwaltung)
# Filling in 17 Missing Values for: Lorenz Hess
# Filling in 1 Missing Values for: Albert Rösti
# Filling in 10 Missing Values for: Verwaltungsrecht (Österreich)
# Filling in 141 Missing Values for: Neue psychoaktive Substanzen
# Filling in 155 Missing Values for: Staatsanwaltschaft (Liechtenstein)
# Filling in 101 Missing Values for: National Defense Authorization Act for Fiscal Year 2012
# Filling in 83 Missing Values for: Arraiolos-Gruppe
# Filling in 64 Missing Values for: Nationaler Sicherheits- und Verteidigungsrat der Ukraine
# Filling in 130 Missing Values for: Christine Bulliard-Marbach
# Filling in 17 Missing Values for: Triade (Kultur)
# Filling in 117 Missing Values for: Hôpital général
# Filling in 174 Missing Values for: Nauruische Regierung
# Filling in 48 Missing Values for: Thomas Hutchinson (Gouverneur)
# Filling in 170 Missing Values for: Regierung des Großherzogtums Hessen
# Filling in 1 Missing Values for: Wahlrecht in den deutschen Einzelstaaten bis 1918
# Filling in 86 Missing Values for: Bundes-Schariagericht
# Filling in 3 Missing Values for: Polizei (Saudi-Arabien)
# Filling in 1 Missing Values for: Lobbyregister
# Filling in 54 Missing Values for: Provisorische Regierung (Schleswig-Holstein)
# Filling in 4 Missing Values for: Transparenz-Register
# Filling in 67 Missing Values for: Hans Wicki
# Filling in 10 Missing Values for: Tourismuspolitik
# Filling in 1 Missing Values for: Verfassung der Demokratischen Volksrepublik Korea
# Filling in 9 Missing Values for: Regierung der Deutschsprachigen Gemeinschaft
# Filling in 33 Missing Values for: Verwaltungskostengesetz
# Filling in 11 Missing Values for: Ministerium der Deutschsprachigen Gemeinschaft
# Filling in 23 Missing Values for: Reichsgesetz über die Einführung einer provisorischen Zentralgewalt für Deutschland
# Filling in 7 Missing Values for: Valbirse
# Filling in 124 Missing Values for: Nassauische Verfassung von 1814
# Filling in 8 Missing Values for: Die Transformation der Demokratie
# Filling in 6 Missing Values for: Ministerverantwortlichkeit
# Filling in 98 Missing Values for: Liste der Abgeordneten zum Vorarlberger Landtag (XXX. Gesetzgebungsperiode)
# Filling in 73 Missing Values for: Tunesische Regierung
# Filling in 65 Missing Values for: Landesrechnungshof Nordrhein-Westfalen
# Filling in 13 Missing Values for: Bundesregierung Somalias
# Filling in 60 Missing Values for: Liste der Staatspräsidenten Sri Lankas
# Filling in 75 Missing Values for: Verteidigungsministerium (Polen)
# Filling in 106 Missing Values for: Römisches Marschlager von Wilkenburg
# No Data Availible for: FBI-Untersuchung des Umgangs mit offiziellen Unterlagen durch Donald Trump
# No Data Availible for: Alberto Lepori
# No Data Availible for: Ministerpräsident von Sachsen-Anhalt
# No Data Availible for: Fredy Lindegger
# No Data Availible for: Karin Fehr Thoma
# No Data Availible for: Verfassung Haitis
# No Data Availible for: Karl-Heinz Zeller
# No Data Availible for: Peter Peyer
# Working on... Adolf Hitler
# at 0 / 1393
# Working on... Algerien
# at 1 / 1393
# Working on... Betäubungsmittelgesetz (Deutschland)
# at 2 / 1393
# Working on... Bodensee
# at 3 / 1393
# Working on... Freie Hansestadt Bremen
# at 4 / 1393
# Working on... Bulgarien
# at 5 / 1393
# Working on... Bundesregierung (Deutschland)
# at 6 / 1393
# Working on... Charlie Chaplin
# at 7 / 1393
# Working on... Zeit des Nationalsozialismus
# at 8 / 1393
# Working on... Dresden
# at 9 / 1393
# Working on... Demokratie
# at 10 / 1393
# Working on... Düsseldorf
# at 11 / 1393
# Working on... Eritrea
# at 12 / 1393
# Working on... Elfenbeinküste
# at 13 / 1393
# Working on... Französische Revolution
# at 14 / 1393
# Working on... George W. Bush
# at 15 / 1393
# Working on... Grönland
# at 16 / 1393
# Working on... Geschichte Europas
# at 17 / 1393
# Working on... Gefangener
# at 18 / 1393
# Working on... Globalisierungskritik
# at 19 / 1393
# Working on... Humboldt-Universität zu Berlin
# at 20 / 1393
# Working on... Indien
# at 21 / 1393
# Working on... Kairo
# at 22 / 1393
# Working on... Kanada
# at 23 / 1393
# Working on... Kalifornien
# at 24 / 1393
# Working on... Krieg
# at 25 / 1393
# Working on... Liestal
# at 26 / 1393
# Working on... Liechtenstein
# at 27 / 1393
# Working on... Nordrhein-Westfalen
# at 28 / 1393
# Working on... Norrköping
# at 29 / 1393
# Working on... Niedersachsen
# at 30 / 1393
# Working on... Norwegen
# at 31 / 1393
# Working on... Niccolò Machiavelli
# at 32 / 1393
# Working on... New York (Bundesstaat)
# at 33 / 1393
# Working on... Platon
# at 34 / 1393
# Working on... Polen
# at 35 / 1393
# Working on... Politisches Spektrum
# at 36 / 1393
# Working on... Recht
# at 37 / 1393
# Working on... Republik
# at 38 / 1393
# Working on... Schweiz
# at 39 / 1393
# Working on... Saarland
# at 40 / 1393
# Working on... Schleswig-Holstein
# at 41 / 1393
# Working on... Toulouse
# at 42 / 1393
# Working on... Terroranschläge am 11. September 2001
# at 43 / 1393
# Working on... Theodor Heuss
# at 44 / 1393
# Working on... Kanton Thurgau
# at 45 / 1393
# Working on... Thüringen
# at 46 / 1393
# Working on... Tschechien
# at 47 / 1393
# Working on... Uster
# at 48 / 1393
# Working on... Ungarn
# at 49 / 1393
# Working on... Ukraine
# at 50 / 1393
# Working on... Vereinte Nationen
# at 51 / 1393
# Working on... Vietnam
# at 52 / 1393
# Working on... Wiener Kongress
# at 53 / 1393
# Working on... 1939
# at 54 / 1393
# Working on... 18. Jahrhundert
# at 55 / 1393
# Working on... 4. Juli
# at 56 / 1393
# Working on... 1958
# at 57 / 1393
# Working on... 10. Februar
# at 58 / 1393
# Working on... 1971
# at 59 / 1393
# Working on... 1967
# at 60 / 1393
# Working on... 1996
# at 61 / 1393
# Working on... 21. September
# at 62 / 1393
# Working on... 20. Oktober
# at 63 / 1393
# Working on... 1785
# at 64 / 1393
# Working on... 1710
# at 65 / 1393
# Working on... Europäische Union
# at 66 / 1393
# Working on... Brasilien
# at 67 / 1393
# Working on... Bundespräsident (Deutschland)
# at 68 / 1393
# Working on... Bundespräsident (Österreich)
# at 69 / 1393
# Working on... Parlament
# at 70 / 1393
# Working on... Mehrheitswahl
# at 71 / 1393
# Working on... Vereinigtes Königreich
# at 72 / 1393
# Working on... Basel
# at 73 / 1393
# Working on... Uruguay
# at 74 / 1393
# Working on... Venezuela
# at 75 / 1393
# Working on... Kambodscha
# at 76 / 1393
# Working on... Katar
# at 77 / 1393
# Working on... Singapur
# at 78 / 1393
# Working on... Regierung
# at 79 / 1393
# Working on... Ernst Reuter
# at 80 / 1393
# Working on... Bhutan
# at 81 / 1393
# Working on... Monarchie
# at 82 / 1393
# Working on... Kanton Tessin
# at 83 / 1393
# Working on... Bundesrat (Schweiz)
# at 84 / 1393
# Working on... Staatspräsident
# at 85 / 1393
# Working on... St. Gallen
# at 86 / 1393
# Working on... Bundesverfassungsgericht
# at 87 / 1393
# Working on... Gewaltenteilung
# at 88 / 1393
# Working on... Gesetz
# at 89 / 1393
# Working on... Legislative
# at 90 / 1393
# Working on... Ecuador
# at 91 / 1393
# Working on... Bürgermeister
# at 92 / 1393
# Working on... Oberösterreich
# at 93 / 1393
# Working on... Wyoming
# at 94 / 1393
# Working on... Zürich
# at 95 / 1393
# Working on... Präsident der Vereinigten Staaten
# at 96 / 1393
# Working on... Rhode Island
# at 97 / 1393
# Working on... Mailand
# at 98 / 1393
# Working on... Kartäuser
# at 99 / 1393
# Working on... Mitglied des Europäischen Parlaments
# at 100 / 1393
# Working on... Deutsche Kommunistische Partei
# at 101 / 1393
# Working on... Gericht
# at 102 / 1393
# Working on... Diktatur
# at 103 / 1393
# Working on... Menschenrechte
# at 104 / 1393
# Working on... Verfassung der Vereinigten Staaten
# at 105 / 1393
# Working on... Federalist Papers
# at 106 / 1393
# Working on... Kaliningrad
# at 107 / 1393
# Working on... Tirana
# at 108 / 1393
# Working on... Bratislava
# at 109 / 1393
# Working on... Archangelsk
# at 110 / 1393
# Working on... Kanton Zürich
# at 111 / 1393
# Working on... Emergenz
# at 112 / 1393
# Working on... Boston
# at 113 / 1393
# Working on... Pennsylvania
# at 114 / 1393
# Working on... Sofia
# at 115 / 1393
# Working on... Kanton (Schweiz)
# at 116 / 1393
# Working on... Senat
# at 117 / 1393
# Working on... Senat von Berlin
# at 118 / 1393
# Working on... John Locke
# at 119 / 1393
# Working on... Charles de Secondat, Baron de Montesquieu
# at 120 / 1393
# Working on... Canberra
# at 121 / 1393
# Working on... Wallonische Region
# at 122 / 1393
# Working on... Helmut Schmidt
# at 123 / 1393
# Working on... Freiheitliche demokratische Grundordnung
# at 124 / 1393
# Working on... Grundrechte (Deutschland)
# at 125 / 1393
# Working on... Bundeswehr
# at 126 / 1393
# Working on... Frage
# at 127 / 1393
# Working on... Volk
# at 128 / 1393
# Working on... Stanislaus II. August Poniatowski
# at 129 / 1393
# Working on... Franklin D. Roosevelt
# at 130 / 1393
# Working on... Äquatorialguinea
# at 131 / 1393
# Working on... Ermächtigungsgesetz
# at 132 / 1393
# Working on... Bundesmonopolverwaltung für Branntwein
# at 133 / 1393
# Working on... Kalmückien
# at 134 / 1393
# Working on... Afrikanische Union
# at 135 / 1393
# Working on... Oktoberrevolution
# at 136 / 1393
# Working on... Neuzeit
# at 137 / 1393
# Working on... Herisau
# at 138 / 1393
# Working on... Todesstrafe
# at 139 / 1393
# Working on... Öffentlichkeit
# at 140 / 1393
# Working on... Staatspräsident (Polen)
# at 141 / 1393
# Working on... Frieden
# at 142 / 1393
# Working on... Freie Deutsche Jugend
# at 143 / 1393
# Working on... Besatzungsmacht
# at 144 / 1393
# Working on... Okkupation
# at 145 / 1393
# Working on... Werbung
# at 146 / 1393
# Working on... Vorarlberg
# at 147 / 1393
# Working on... Martin Luther King
# at 148 / 1393
# Working on... Polizei
# at 149 / 1393
# Working on... Reichskanzler
# at 150 / 1393
# Working on... Kanton Aargau
# at 151 / 1393
# Working on... Föderalismus
# at 152 / 1393
# Working on... Samoa
# at 153 / 1393
# Working on... Malediven
# at 154 / 1393
# Working on... Freienbach
# at 155 / 1393
# Working on... Kanton Schwyz
# at 156 / 1393
# Working on... Geschichte Belgiens
# at 157 / 1393
# Working on... Republika Srpska
# at 158 / 1393
# Working on... Florida
# at 159 / 1393
# Working on... North Carolina
# at 160 / 1393
# Working on... Dnipro
# at 161 / 1393
# Working on... Simón Bolívar
# at 162 / 1393
# Working on... Lausanne
# at 163 / 1393
# Working on... Geschichte Islands
# at 164 / 1393
# Working on... Santiago de Chile
# at 165 / 1393
# Working on... Pornografie
# at 166 / 1393
# Working on... Kanton Jura
# at 167 / 1393
# Working on... Kanton Bern
# at 168 / 1393
# Working on... Landesregierung von Baden-Württemberg
# at 169 / 1393
# Working on... Sheriff (Vereinigte Staaten)
# at 170 / 1393
# Working on... Verwaltung
# at 171 / 1393
# Working on... Opposition (Politik)
# at 172 / 1393
# Working on... Marianne Birthler
# at 173 / 1393
# Working on... Kanton Solothurn
# at 174 / 1393
# Working on... Davos
# at 175 / 1393
# Working on... Pascal Couchepin
# at 176 / 1393
# Working on... Außenpolitik
# at 177 / 1393
# Working on... Völkerrecht
# at 178 / 1393
# Working on... Studierendenschaft
# at 179 / 1393
# Working on... Allgemeiner Studierendenausschuss
# at 180 / 1393
# Working on... Europäische Kommission
# at 181 / 1393
# Working on... Erstfeld
# at 182 / 1393
# Working on... Direkte Demokratie
# at 183 / 1393
# Working on... Rat der Europäischen Union
# at 184 / 1393
# Working on... Europäisches Parlament
# at 185 / 1393
# Working on... Europäischer Rechnungshof
# at 186 / 1393
# Working on... Volksentscheid
# at 187 / 1393
# Working on... Staatsgewalt
# at 188 / 1393
# Working on... Herrschaft
# at 189 / 1393
# Working on... Volkssouveränität
# at 190 / 1393
# Working on... Staatsoberhaupt
# at 191 / 1393
# Working on... Ministerium
# at 192 / 1393
# Working on... Politisches System der Schweiz
# at 193 / 1393
# Working on... Drei
# at 194 / 1393
# Working on... Lippe (Land)
# at 195 / 1393
# Working on... Zentralafrikanisches Kaiserreich
# at 196 / 1393
# Working on... Absolutismus
# at 197 / 1393
# Working on... Kanton Schaffhausen
# at 198 / 1393
# Working on... Kanton Neuenburg
# at 199 / 1393
# Working on... Jakob Maria Mierscheid
# at 200 / 1393
# Working on... Bordeaux
# at 201 / 1393
# Working on... Kanton Obwalden
# at 202 / 1393
# Working on... Freimaurerei
# at 203 / 1393
# Working on... Kanton Luzern
# at 204 / 1393
# Working on... Bundesverfassung der Schweizerischen Eidgenossenschaft
# at 205 / 1393
# Working on... Hopi
# at 206 / 1393
# Working on... Politische Gemeinde
# at 207 / 1393
# Working on... Verhältniswahl
# at 208 / 1393
# Working on... Philosophie der Neuzeit
# at 209 / 1393
# Working on... George Washington

# %%
#Comparing the Amount of actual Dataset used with all backlinks from the main Page

# %%
print("Amount of pages that got searched",len(filter_all_backlinks))
print("Amount of pages that we got data from",len(backlinksMainview))

# %%
#Zipping both lists together

# %%
Corr2list = []
for e in range(len(entrys)):
    numvieww = mainviews[e]
    sumbl = entrys[e]
    Corr2list.append([numvieww,sumbl])

# %%
corr2 = pd.DataFrame(Corr2list, columns=[f'{article} views', "Sum backlinks pageview"])
corr2

# %%
#Showing the Correlation between the views of the searched article and the sum of views from Backlinks for each day.

# %%
corr2.corr(method="pearson")
